# %%
for x in range(1,10):
        if x<5:
            print('*'*x)
        else:
            print('*'*(10-x))
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
print(input()[::-1])
# Out:
# zia
# aiz
